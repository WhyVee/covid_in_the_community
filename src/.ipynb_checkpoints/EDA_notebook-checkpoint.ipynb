# %%
import pandas as pd
import random
import numpy as np

# %%
file_path = "../data/COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_Facility.csv"
hospital_data = pd.read_csv(file_path)

# %%
hospital_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209463 entries, 0 to 209462
# Columns: 105 entries, hospital_pk to previous_week_patients_covid_vaccinated_doses_all_7_day_max
# dtypes: bool(1), float64(71), int64(23), object(10)
# memory usage: 166.4+ MB

# %%
hospital_data
# Out:
#                                               hospital_pk collection_week  \
# 0       aab2bb3ab769da90baf57242c96ec481afb5ec6a233784...      2021/05/14
# 1       3b081d5ef1c552538e4af4aa593a857bb922a4f364a412...      2021/05/14
# 2       ee04edd185865c38c839812cb2eb5ae5d3f8922e3b629e...      2021/05/14
# 3       f70d7abf93c78280583ac18e896e6737cca8212b017513...      2021/05/14
# 4                                                  010108      2021/05/14
# ...                                                   ...             ...
# 209458                                             400130      2020/07/31
# 209459                                             400115      2020/07/31
# 209460                                             400110      2020/07/31
# 209461                                             480002      2020/07/31
# 209462                                             480001      2020/07/31
#
#        state     ccn                           hospital_name  \
# ...

# %%
hospital_data['percent_inpatient_beds'] = hospital_data['inpatient_beds_used_7_day_sum'] / hospital_data['inpatient_beds_7_day_sum']

# %%
hospital_data.describe()
# Out:
#                  zip      fips_code  total_beds_7_day_avg  \
# count  209454.000000  209077.000000         208173.000000
# mean    53969.239313   29430.331428           -855.479571
# std     26842.765741   16202.464375          31977.291667
# min       603.000000    1001.000000        -999999.000000
# 25%     33021.000000   17043.000000             29.000000
# 50%     55350.000000   29009.000000             72.000000
# 75%     76063.000000   42091.000000            220.000000
# max     99901.000000   78020.000000          27024.700000
#
#        all_adult_hospital_beds_7_day_avg  \
# count                      203229.000000
# mean                        -1890.382829
# std                         45150.146411
# min                       -999999.000000
# 25%                            26.000000
# 50%                            66.000000
# 75%                           200.000000
# max                         27013.600000
#
#        all_adult_hospital_inpatient_beds_7_day_avg  \
# ...

# %%
#count NaN vals by column
hospital_data.isna().sum()
# Out:
# hospital_pk                                                         0
# collection_week                                                     0
# state                                                               0
# ccn                                                               591
# hospital_name                                                       0
#                                                                 ...
# total_personnel_covid_vaccinated_doses_one_7_day_max           152053
# total_personnel_covid_vaccinated_doses_all_7_day_max           151954
# previous_week_patients_covid_vaccinated_doses_one_7_day_max    152424
# previous_week_patients_covid_vaccinated_doses_all_7_day_max    152360
# percent_inpatient_beds                                           2879
# Length: 106, dtype: int64

# %%
hospital_nand = hospital_data.replace(-999999.0)

# %%
hospital_nand.describe()
# Out:
#                  zip      fips_code  total_beds_7_day_avg  \
# count  209454.000000  209077.000000         208172.000000
# mean    53969.239313   29430.331428            167.842764
# std     26842.765741   16202.464375            246.244651
# min       603.000000    1001.000000              0.000000
# 25%     33021.000000   17043.000000             29.000000
# 50%     55350.000000   29009.000000             72.000000
# 75%     76063.000000   42091.000000            220.300000
# max     99901.000000   78020.000000          27024.700000
#
#        all_adult_hospital_beds_7_day_avg  \
# count                      203208.000000
# mean                          151.909226
# std                           221.254441
# min                             0.000000
# 25%                            26.000000
# 50%                            66.000000
# 75%                           200.000000
# max                         27013.600000
#
#        all_adult_hospital_inpatient_beds_7_day_avg  \
# ...

# %%
hospital_nand[hospital_nand['city'].isna()]
# Out:
#                                               hospital_pk collection_week  \
# 0       aab2bb3ab769da90baf57242c96ec481afb5ec6a233784...      2021/05/14
# 1       3b081d5ef1c552538e4af4aa593a857bb922a4f364a412...      2021/05/14
# 5000    3b081d5ef1c552538e4af4aa593a857bb922a4f364a412...      2021/05/07
# 5001    aab2bb3ab769da90baf57242c96ec481afb5ec6a233784...      2021/05/07
# 10004   ff9032c172057190bf52f523d253c79af2d5f74d007084...      2021/04/30
# ...                                                   ...             ...
# 204581  3b081d5ef1c552538e4af4aa593a857bb922a4f364a412...      2020/07/31
# 204582  ff9032c172057190bf52f523d253c79af2d5f74d007084...      2020/07/31
# 204584  e519c5cd272a8e72aade05f0de477b125aa43b706020b8...      2020/07/31
# 204586  36db6bad3679dfdcccc301fc608438109ad907943c702f...      2020/07/31
# 204587  75171dc6164bbf4edc0de7a03d2960f66b925c38d1d554...      2020/07/31
#
#        state  ccn                         hospital_name address city      zip  \
# ...

# %%
len(hospital_nand.zip.unique())
# Out:
# 4458

# %%
list(hospital_nand['collection_week'])
# Out:
# ['2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
#  '2021/05/14',
# ...

# %%
chosen_features_list = ['collection_week',
 'zip',
 'total_beds_7_day_sum',
 'all_adult_hospital_beds_7_day_sum',
 'all_adult_hospital_inpatient_beds_7_day_sum',
 'inpatient_beds_used_7_day_sum',
 'all_adult_hospital_inpatient_bed_occupied_7_day_sum',
 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum',
 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum',
 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum',
 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum',
 'inpatient_beds_7_day_sum',
 'total_icu_beds_7_day_sum',
 'total_staffed_adult_icu_beds_7_day_sum',
 'icu_beds_used_7_day_sum',
 'staffed_adult_icu_bed_occupancy_7_day_sum',
 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum',
 'staffed_icu_adult_patients_confirmed_covid_7_day_sum',
 'total_patients_hospitalized_confirmed_influenza_7_day_sum',
 'icu_patients_confirmed_influenza_7_day_sum',
 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum',
 'percent_inpatient_beds',
 'geocoded_hospital_address']
len(chosen_features_list)
# Out:
# 23

# %%
list(hospital_nand.columns)
# Out:
# ['hospital_pk',
#  'collection_week',
#  'state',
#  'ccn',
#  'hospital_name',
#  'address',
#  'city',
#  'zip',
#  'hospital_subtype',
#  'fips_code',
#  'is_metro_micro',
#  'total_beds_7_day_avg',
#  'all_adult_hospital_beds_7_day_avg',
#  'all_adult_hospital_inpatient_beds_7_day_avg',
#  'inpatient_beds_used_7_day_avg',
#  'all_adult_hospital_inpatient_bed_occupied_7_day_avg',
#  'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg',
#  'total_adult_patients_hospitalized_confirmed_covid_7_day_avg',
#  'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg',
#  'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg',
#  'inpatient_beds_7_day_avg',
#  'total_icu_beds_7_day_avg',
#  'total_staffed_adult_icu_beds_7_day_avg',
#  'icu_beds_used_7_day_avg',
#  'staffed_adult_icu_bed_occupancy_7_day_avg',
#  'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg',
# ...

# %%
hospital_nand[hospital_nand['geocoded_hospital_address'].isna()]
# Out:
#        hospital_pk collection_week state     ccn  \
# 19          011304      2021/05/14    AL  011304
# 20          010174      2021/05/14    AL  010174
# 23          010073      2021/05/14    AL  010073
# 34          010012      2021/05/14    AL  010012
# 68          010131      2021/05/14    AL  010131
# ...            ...             ...   ...     ...
# 209458      400130      2020/07/31    PR  400130
# 209459      400115      2020/07/31    PR  400115
# 209460      400110      2020/07/31    PR  400110
# 209461      480002      2020/07/31    VI  480002
# 209462      480001      2020/07/31    VI  480001
#
#                                  hospital_name  \
# 19                    CHOCTAW GENERAL HOSPITAL
# 20         THOMASVILLE REGIONAL MEDICAL CENTER
# 23                        CLAY COUNTY HOSPITAL
# 34              DEKALB REGIONAL MEDICAL CENTER
# 68                    CRESTWOOD MEDICAL CENTER
# ...                                        ...
# ...

# %%
hospital_nand['lon'] = hospital_nand.geocoded_hospital_address.x
hospital_nand['lat'] = hospital_nand.geocoded_hospital_address.y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-161-679148b87a86> in <module>
# ----> 1 hospital_nand['lon'] = hospital_nand.geocoded_hospital_address.x
#       2 hospital_nand['lat'] = hospital_nand.geocoded_hospital_address.y
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'x'

# %%
hospital_chosen = hospital_nand[chosen_features_list]
hospital_chosen_zip = hospital_chosen[hospital_chosen['zip'].notna()]
hospital_chosen_zip.set_index('collection_week', inplace=True)
hospital_chosen_zip = hospital_chosen_zip.iloc[::-1]

# %%
grouped_hospital = hospital_chosen_zip.groupby('zip')

# %%
group_names = grouped_hospital.groups.keys()

# %%
group_names = list(group_names)

g = random.choice(group_names)
print(g)
grouped_hospital.get_group(g)[['inpatient_beds_used_7_day_sum', 'inpatient_beds_7_day_sum']].plot()
# Out:
# 86040.0
# <AxesSubplot:xlabel='collection_week'>
